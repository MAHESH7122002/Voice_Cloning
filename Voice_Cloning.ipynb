# %%
#@title VOICE CLONING TTS


from IPython.display import display, HTML

# HTML code
html = """
<!DOCTYPE html>
<html>
  <head>
    <meta charset="UTF-8">
    <title>Welcome</title>
    <style>
      body {
        font-family: Arial, sans-serif;
        background-color: black;
        margin: 0;
        padding: 0;
        color: white;
      }

      .container {
        width: 100%;
        height: 100%;
        display: flex;
        justify-content: center;
        align-items: center;
      }

      .content {
        display: flex;
        flex-direction: column;
        align-items: center;
        text-align: center;
        max-width: 800px;
      }

      h1 {
        font-size: 4rem;
        color: #00ff00;
        margin-top: 0;
      }

      p {
        font-size: 1.5rem;
        color: grey;
        margin-bottom: 2rem;
      }

      .image-container {
        display: flex;
        justify-content: center;
        margin-bottom: 2rem;
      }

      img {
        max-width: 100%;
        max-height: 100%;
      }
    </style>
  </head>
  <body>
    <div class="container">
      <div class="content">
        <h1>Voice cloning app</h1>
        <p>by Surge Mafia.</p>
        <div class="image-container">
          <img src="data:image/png;base64,...">
        </div>

      </div>
    </div>
  </body>
</html>


"""
display(HTML(html))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="UTF-8">
#     <title>Welcome</title>
#     <style>
#       body {
#         font-family: Arial, sans-serif;
#         background-color: black;
#         margin: 0;
#         padding: 0;
#         color: white;
#       }
#
#       .container {
#         width: 100%;
#         height: 100%;
#         display: flex;
#         justify-content: center;
#         align-items: center;
#       }
#
#       .content {
#         display: flex;
#         flex-direction: column;
#         align-items: center;
#         text-align: center;
#         max-width: 800px;
#       }
#
#       h1 {
#         font-size: 4rem;
#         color: #00ff00;
#         margin-top: 0;
#       }
#
#       p {
#         font-size: 1.5rem;
#         color: grey;
#         margin-bottom: 2rem;
#       }
#
#       .image-container {
#         display: flex;
#         justify-content: center;
#         margin-bottom: 2rem;
#       }
#
#       img {
# ...

# %% [markdown]
# # **Voice Cloning**
#
# Voice cloning is the creation of an artificial simulation of a person’s voice. Today’s AI software methods are capable of generating synthetic speech that closely resembles a targeted human voice. In some cases, the difference between the real and fake voice is imperceptible to the average person.
#
# ## **Use Cases:**
# First, the bad...
#
# **Voice is a unique personal identifier that is readily accessible to fraudsters. This is certainly true for public figures including celebrities, politicians and business leaders, but the reality is that anyone could be a target. Online videos, speeches, conference calls, phone conversations and social media posts can all be used to gather the data needed to train a system to clone a voice.**
#
# * **Voice biometric spoofing:** Voice is a unique identifier and reliable measure for biometric security. However, criminals can use presentation attacks including recorded voice, computer-altered voice and synthetic voice, or voice cloning, to fool voice biometric systems into thinking they hear the real, authorized user and grant access to sensitive information and accounts.
# * **Phishing scams:** Online AI voice cloning software also enables a new breed of phishing scams that exploit the fact that a victim believes they are talking to someone they trust. Last year, a UK-based CEO was tricked into transferring more than $240,000 based on a phone call that he believed was from his boss, the CEO of the organization’s German parent company.
#
# * **Misinformation:** Fake news and similar forms of misinformation pose a serious threat. Many of us are familiar with how manipulated video to impact the political landscape.
#
# * **Evidence:** Synthetic voices and other deepfakes could be used to create fake evidence that impacts criminal cases. While checks exist to validate audio and video evidence presented in court, preventing these tactics from influencing testimony based on what people believe they saw or heard may be a challenge.
#
# * **Blackmail and bullying:** Manipulated video and audio of people doing or saying things they didn’t do our say can be used for online bullying and threats to expose fake, embarrassing content if victims refuse to pay a fee.
#
# Firstly Good,
#
# * **Education:** Cloning the voices of historical figures offers new opportunities for interactive teaching and dynamic storytelling.
#
# * **Audiobooks:** Using AI voice cloning software, celebrity voices can be used to narrate books, autobiographies can be read by the author, and historical figures can tell their stories in their own voices. The result is an immersive, high-quality listening experience.
#
# * **Assistive Tech:** Synthetic voices can be used to assist persons with disabilities or health issues that impact their speech.

# %% [markdown]
# # **Tortoise TTS**
#
# **TorToiSe is a text-to-speech (TTS) program which can mimic voices given 2-4 examples. It is composed of five separately-trained neural networks that are pipelined together to produce the final output. This document will first go into details about each of the five models that make up Tortoise, and will wrap up with a system-level description of how they interoperate.**
#
# ##Models:
# * The Autoregressive Decoder
# * CLVP (Contrastive Language Voice Pretaining)
# * CVVP (Contrastive Voice-Voice Pretaining)
# * The Diffusion Decoder
# * The Vocoder

# %%
import shutil
#@markdown Select the preset:
preset_to_use = "high_quality" #@param ["ultra_fast", "fast", "standard", "high_quality"]
voice_to_use = "custom_voice" #@param ["custom_voice","angie", "applejack", "daniel", "deniro", "emma", "freeman", "geralt", "halle" , "jlaw", "mol", "pat", "pat2", "rainbow", "snakes", "tim_raynolds","tom","train_atkins","train_daws","train_dotrice","train_dreams","train_grace","train_kennard","train_lescault","train_mouse","weaver","william"]
cvvp_amount_to_use = 0.5 #@param {type:"number"}
#@markdown ( default cvvp_amount = float(0.5) )
print("Installing dependencies....")
# Out:
# Installing dependencies....

# %%
# install all dependencies
# !pip3 -q install -U scipy
# !pip3 -q install cog
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 414.1/414.1 kB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 54.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.9 MB/s eta 0:00:00

# %%
# !git clone https://github.com/afiaka87/tortoise-tts.git
# Out:
# Cloning into 'tortoise-tts'...
# remote: Enumerating objects: 1458, done.
# remote: Counting objects: 100% (402/402), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 1458 (delta 357), reused 351 (delta 351), pack-reused 1056
# Receiving objects: 100% (1458/1458), 53.54 MiB | 30.48 MiB/s, done.
# Resolving deltas: 100% (594/594), done.

# %%
# %cd tortoise-tts
# !pip3 -q install transformers==4.19.0
# !pip3 -q install -r requirements.txt
file_id = "1FBRCKJjAP75oQVODYug4Y1vRvSka13Zk"
# !gdown --id {file_id}
# !sleep(2)
# !python3 setup.py install
# !sleep(5)
# !pip3 -q install -r requirements_2.txt
# %cd tortoise/voices
# !mkdir custom_voice
# Out:
# /content/tortoise-tts
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 56.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 74.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 51.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 13.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 21.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.9/252.9 kB 23.1 MB/s eta 0:00:00
# ...

# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import your custom voice
path_mp3 = "/content/drive/MyDrive/voice_clone/custom_voice.mp3"
with open(path_mp3, 'rb') as f:
  content = f.read()

# %%
# definition of custom_voice files for copy
src_mp3_path = "/content/drive/MyDrive/voice_clone/custom_voice.mp3"
dst_mp3_path = "/content/tortoise-tts/tortoise/voices/custom_voice/"
dst_txt_path = "/content/"

# %%
# copy files from Google Drive to Google Colab.
shutil.copy(src_mp3_path, dst_mp3_path)
# Out:
# '/content/tortoise-tts/tortoise/voices/custom_voice/custom_voice.mp3'

# %%
# back to folder
# %cd /content/tortoise-tts
# Out:
# /content/tortoise-tts

# %%
# import all libraries

import os, sys
import subprocess
import tempfile
from time import time
import warnings
from cog import BasePredictor, Path
import torch
import torchaudio
import torch.nn as nn
import torch.nn.functional as F
import IPython
from IPython.display import clear_output
from tortoise.api import TextToSpeech, format_conditioning
from tortoise.utils.audio import load_audio, get_voices, load_voice, load_voices
from tortoise.utils.tokenizer import VoiceBpeTokenizer
from tortoise.utils.text import split_and_recombine_text
from tortoise.api import TextToSpeech

# %%
# clear the terminal screen
def screen_clear():
  clear_output(wait=False)

# %%
# Load the models
tts = TextToSpeech()
# Out:
# ...
#   0% (0 of 1716988501) |                 | Elapsed Time: 0:00:00 ETA:  --:--:--
# ...
# 100% (1716988501 of 1716988501) |########| Elapsed Time: 0:00:09 Time:  0:00:09
# Done.
#   0% (0 of 1169472627) |                 | Elapsed Time: 0:00:00 ETA:  --:--:--
# ...
# 100% (1169472627 of 1169472627) |########| Elapsed Time: 0:00:04 Time:  0:00:04
# Done.
# ...
# 100% (975620731 of 975620731) |##########| Elapsed Time: 0:00:10 Time:  0:00:10
# Done.
#   0% (0 of 391384715) |                  | Elapsed Time: 0:00:00 ETA:  --:--:--
# ...
# 100% (391384715 of 391384715) |##########| Elapsed Time: 0:00:03 Time:  0:00:03
# Done.

# %%
# silence warnings
warnings.filterwarnings("ignore")

# %%
# set the tortoise paths
MODULE_DIRECTORY = os.path.dirname("tortoise-tss")
CUSTOM_VOICE_DIRECTORY = Path(MODULE_DIRECTORY, "tortoise", "voices", "custom_voice")
folder_path = Path(CUSTOM_VOICE_DIRECTORY)

# %%
#if only one file in list, save name to variable file_name
files = list(folder_path.glob("*"))
if len(files) == 1:
    file_name = files[0].name
    print(file_name)
else:
    print("In the folder is not any file, or there is more than one.")
# Out:
# custom_voice.mp3

# %%
# set the voice paths
CUSTOM_VOICE_FILE = Path(CUSTOM_VOICE_DIRECTORY, file_name)
outpath = "/content/results/"
textfile_path = "../custom_speech.txt"
CUSTOM_VOICE_NAME = voice_to_use
voice_outpath = os.path.join(outpath, CUSTOM_VOICE_NAME)

# %%
# Function to create custom_voice from .mp3 file
def create_custom_voice_from_mp3(input_path: str, segment_time: int = 9) -> None:
    CUSTOM_VOICE_DIRECTORY.mkdir(parents=True, exist_ok=True)
    normalized_audio_path = tempfile.mktemp(suffix=".wav")
    result = subprocess.run([
            "ffmpeg-normalize",
            input_path,
            "-c:a",
            "libmp3lame",
            "-b:a",
            "192k",
            "-o",
            normalized_audio_path,], stdout=subprocess.PIPE)
    try:
      output = subprocess.check_output(
        [
            "ffmpeg-normalize",
            input_path,
            "-c:a",
            "libmp3lame",
            "-b:a",
            "192k",
            "-o",
            normalized_audio_path,
        ],
        stderr=subprocess.STDOUT,
    )
    except subprocess.CalledProcessError as e:
      print(e.output.decode('utf-8'))
    assert os.path.exists(normalized_audio_path), "ffmpeg-normalize failed"
    result = subprocess.run(   [
            "ffmpeg",
            "-v",
            "warning",  # log only errors
            "-ss",
            "00:00:00",
            "-t",
            #"300", # limit to 300 seconds (~30 segments)
            "500", # limit to 300 seconds (~40 segments)
            #"500",  # limit to 300 seconds (~50 segments)
            "-i",
            normalized_audio_path,
            "-acodec",
            "pcm_s16le",
            "-ac",
            "1",
            "-f",
            "segment",
            "-segment_time",
            str(segment_time),
            os.path.join(CUSTOM_VOICE_DIRECTORY, "%d.wav"),
        ])

    subprocess.check_output(
        [
            "ffmpeg",
            "-v",
            "warning",  # log only errors
            "-ss",
            "00:00:00",
            "-t",
            #"300", # limit to 300 seconds (~30 segments)
            "500",  # limit to 300 seconds (~30 segments)
            "-i",
            normalized_audio_path,
            "-acodec",
            "pcm_s16le",
            "-ac",
            "1",
            "-f",
            "segment",
            "-segment_time",
            str(segment_time),
            os.path.join(CUSTOM_VOICE_DIRECTORY, "%d.wav"),
        ]
    )

# %%
# init of the text variable
text = ""

class Predictor(BasePredictor):
    def predict(text_to_say: str = text, voice_a: str = voice_to_use,custom_voice: Path = CUSTOM_VOICE_FILE,voice_b: str = "disabled",voice_c: str = "disabled",preset_to_use: str = preset_to_use,seed: int= (time()),cvvp_amount: float = cvvp_amount_to_use) -> Path:
        output_dir = Path(tempfile.mkdtemp())

        if custom_voice is not None:
            assert (
                custom_voice.suffix == ".mp3"
            ), f"File {custom_voice} is not an mp3 file"
            if voice_to_use == "custom_voice":
              create_custom_voice_from_mp3(str(custom_voice))
              print(f"Creating voice from {custom_voice}")
            else:
              pass
            all_voices = [voice_to_use]
        else:
            all_voices = [voice_to_use]
        if voice_b != "disabled":
            all_voices.append("custom_voice")
        if voice_c != "disabled":
            all_voices.append(voice_c)
        print(f"Generating text using voices: {all_voices}")


        #text = "Hello guys" #@param {type:"string"}
        text=""
        if text == "":
          src_txt_path = "/content/drive/MyDrive/voice_clone/custom_speech.txt"
          shutil.copy(src_txt_path, dst_txt_path)
          path_txt = "/content/drive/MyDrive/voice_clone/custom_speech.txt"
          with open(path_txt, 'rb') as f:
            content = f.read()
        # Textfile process
          with open(textfile_path, 'r', encoding='utf-8') as f:
              text = ' '.join([l for l in f.readlines()])
              if '|' in text:
                  print("Found the '|' character in your text, which I will use as a cue for where to split it up. If this was not"
                        "your intent, please remove all '|' characters from the input.")
                  texts = text.split('|')
              else:
                  texts = split_and_recombine_text(text)
        else:
          texts = text

        seed = 0 #int(time())

        os.makedirs(voice_outpath, exist_ok=True)

        voice_samples, conditioning_latents = load_voice(CUSTOM_VOICE_NAME)
        all_parts = []

        # generating your custom_voice reading
        for j, text in enumerate(texts):
            gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents,
                                      preset=preset_to_use, k=1, use_deterministic_seed=seed,cvvp_amount=cvvp_amount)
            gen = gen.squeeze(0).cpu()
            torchaudio.save(os.path.join(voice_outpath, f'{j}.wav'), gen, 24000)
            all_parts.append(gen)
        # save your custom_voice reading to "en1.wav" file
        full_audio = torch.cat(all_parts, dim=-1)
        torchaudio.save(os.path.join(voice_outpath, 'result.wav'), full_audio, 24000)

# %%
def exit(code):
    print('\nExiting....')
    print('\nHave a good day.')
    sys.exit(code)

def main():
    try:
      screen_clear()
      Predictor.predict()
      screen_clear()
      print("\nDone !  Your file is saved on your Google Drive !")
    except KeyboardInterrupt:
      exit(1)

# %%
dst_final_file = "/content/drive/MyDrive/"
if voice_to_use == "custom_voice":
  src_final_file = "/content/results/custom_voice/result.wav"
else:
  src_final_file = f"/content/results/{voice_to_use}/result.wav"
def move_to_drive():
  shutil.move(src_final_file, dst_final_file)

if __name__ == '__main__':
  main()
  move_to_drive()
  exit(0) # run the main program
# Out:
# Done !  Your file is saved on your Google Drive !
#
# Exiting....
#
# Have a good day.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
#@title Listen  Source file.

from IPython.display import Audio

# HTML code
html = """
<!DOCTYPE html>
<html>
  <head>
    <meta charset="UTF-8">
    <title>Welcome</title>
    <style>
      body {
        font-family: Arial, sans-serif;
        background-color: black;
        margin: 0;
        padding: 0;
        color: white;
      }

      .container {
        width: 100%;
        height: 100%;
        display: flex;
        justify-content: center;
        align-items: center;
      }

      .content {
        display: flex;
        flex-direction: column;
        align-items: center;
        text-align: center;
        max-width: 800px;
      }

      h1 {
        font-size: 4rem;
        color: #00ff00;
        margin-top: 0;
      }

      p {
        font-size: 1.5rem;
        color: grey;
        margin-bottom: 2rem;
      }

    </style>
  </head>
  <body>
    <div class="container">
      <div class="content">
        <h1>Audio File</h1>
        <p>Output File</p>

      </div>
    </div>
  </body>
</html>


"""
display(HTML(html))
Audio('/content/drive/MyDrive/voice_clone/custom_voice.mp3')
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="UTF-8">
#     <title>Welcome</title>
#     <style>
#       body {
#         font-family: Arial, sans-serif;
#         background-color: black;
#         margin: 0;
#         padding: 0;
#         color: white;
#       }
#
#       .container {
#         width: 100%;
#         height: 100%;
#         display: flex;
#         justify-content: center;
#         align-items: center;
#       }
#
#       .content {
#         display: flex;
#         flex-direction: column;
#         align-items: center;
#         text-align: center;
#         max-width: 800px;
#       }
#
#       h1 {
#         font-size: 4rem;
#         color: #00ff00;
#         margin-top: 0;
#       }
#
#       p {
#         font-size: 1.5rem;
#         color: grey;
#         margin-bottom: 2rem;
#       }
#
#     </style>
#   </head>
#   <body>
#     <div class="container">
#       <div class="content">
#         <h1>Audio File</h1>
#         <p>Source File</p>
#
# ...

# %%
#@title Listen Output file.

from IPython.display import Audio

# HTML code
html = """
<!DOCTYPE html>
<html>
  <head>
    <meta charset="UTF-8">
    <title>Welcome</title>
    <style>
      body {
        font-family: Arial, sans-serif;
        background-color: black;
        margin: 0;
        padding: 0;
        color: white;
      }

      .container {
        width: 100%;
        height: 100%;
        display: flex;
        justify-content: center;
        align-items: center;
      }

      .content {
        display: flex;
        flex-direction: column;
        align-items: center;
        text-align: center;
        max-width: 800px;
      }

      h1 {
        font-size: 4rem;
        color: #00ff00;
        margin-top: 0;
      }

      p {
        font-size: 1.5rem;
        color: grey;
        margin-bottom: 2rem;
      }

    </style>
  </head>
  <body>
    <div class="container">
      <div class="content">
        <h1>Audio File</h1>
        <p>Source File</p>

      </div>
    </div>
  </body>
</html>


"""
display(HTML(html))
Audio('/content/drive/MyDrive/result.wav')
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="UTF-8">
#     <title>Welcome</title>
#     <style>
#       body {
#         font-family: Arial, sans-serif;
#         background-color: black;
#         margin: 0;
#         padding: 0;
#         color: white;
#       }
#
#       .container {
#         width: 100%;
#         height: 100%;
#         display: flex;
#         justify-content: center;
#         align-items: center;
#       }
#
#       .content {
#         display: flex;
#         flex-direction: column;
#         align-items: center;
#         text-align: center;
#         max-width: 800px;
#       }
#
#       h1 {
#         font-size: 4rem;
#         color: #00ff00;
#         margin-top: 0;
#       }
#
#       p {
#         font-size: 1.5rem;
#         color: grey;
#         margin-bottom: 2rem;
#       }
#
#     </style>
#   </head>
#   <body>
#     <div class="container">
#       <div class="content">
#         <h1>Audio File</h1>
#         <p>Source File</p>
#
# ...
